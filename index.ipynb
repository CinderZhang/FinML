# %% [markdown]
# # Machine Learning and Data science(Coder and Non-Coders)
#
# #### *From Data to Knowledge*
#
# ## 0. Before Start...Understand your computer system
# [NTU programmer survival guides](https://personal.ntu.edu.sg/ehchua/programming/index.html)
#
# ## 1. To Start
#
# ### Tutorial
#
# #### Flowchart
#
# [Basic Concepts](https://medium.com/@amanuelabraham0202/flowcharts-for-programmers-2aff6a6d8f63)
#
# [Microsoft Visio](https://support.microsoft.com/en-us/office/create-a-basic-flowchart-in-visio-e207d975-4a51-4bfa-a356-eeec314bd276)
#
# #### Python Coder
#
# [Python for Everyone](https://www.youtube.com/watch?v=8DvywoWv6fI)
#
# [Kaggle-Python, Data, ML, Viz and more--Must See](https://www.kaggle.com/learn/overview)
#
# [Fast AI](https://course.fast.ai/)
# * [To Start](https://course.fast.ai/videos/?lesson=1)
#
# [With ChatGPT](https://cinderzhang.github.io/FinnData)
# * [Assignment Prompt](https://github.com/CinderZhang/FinnData/blob/main/chatGPT_AssignmentSample.md)
#
# [Financial Packages](https://github.com/wilsonfreitas/awesome-quant)
# * [Chinese Market](https://github.com/thuquant/awesome-quant)
#
# [Checkio for educator--Need some coding experience--Need PyCharm](https://checkio.org/teachers/)
#
# [PyCharm for education--from begining to intermediate](https://www.jetbrains.com/edu-products/teaching/)
#
# #### Non-coder or light coder
#
# [Dataiku-Good place to start with almost no coding (at begining)](https://academy.dataiku.com/)
#
#
# ### IDE and online coding platform
#
# [Anaconda--Data science oriented--Jupitur notebook integrated in it](https://www.anaconda.com/)
#
# [PyCharm--General IDE. Use it together with Anaconda](https://www.jetbrains.com/pycharm-edu/)
#
# [Google colab--web browser based--No installation required](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
#
# ### Lot of it
# * [GitHub Project](https://github.com/ujjwalkarn/Machine-Learning-Tutorials)
#
# * * This repository contains a topic-wise curated list of Machine Learning and Deep Learning tutorials, articles and other resources. Other awesome lists can be found in this [list](https://github.com/sindresorhus/awesome).

# %% [markdown]
# ## 2. Use Cases
#
# ### Classics
# * [Fraud Detection](https://www.kaggle.com/arjunjoshua/predicting-fraud-in-financial-payment-services)
#
# * [Fed Speeches](https://www.kaggle.com/datasets/natanm/federal-reserve-governors-speeches-1996-2020/code?select=fed_speeches_1996_2020.csv)
#
# ### General
# * [From Kaggle-update quickly](https://www.kaggle.com/tags/finance)
# * [Dataiku Gallery](http://gallery.dataiku.com/home/)
# * [Dataiku Sample](https://www.dataiku.com/learn/samples/)

# %% [markdown]
# ## 3. Data
#
# * [Google Dataset Search](https://datasetsearch.research.google.com/)
# * * [Instruction for it](https://towardsdatascience.com/google-just-published-25-million-free-datasets-d83940e24284)
# * [SEC Company Search](https://www.sec.gov/edgar/searchedgar/companysearch.html)
# * * SEC has many version of search interfaces. I personally like this one. It allows you to download Excel files for financial statements.
# * [WRDS](https://wrds-www.wharton.upenn.edu/)
# * * Wharton Research Data Services.
# * [Wall Street Journal](www.wsj.com)
# * * [WSJ bond benchmarks](https://www.wsj.com/market-data/bonds/benchmarks)
# * [Yahoo! Finance](finance.yahoo.com)
# * * Still one of the best for historical stock price.
# * [Fannie Mae Loan Performance](https://capmrkt.fanniemae.com/portal/funding-the-market/data/loan-performance-data.html)
# * [Blockchain Coins and more](https://studio.glassnode.com/catalog)
# * [Fedral Reserve St. Louis](https://research.stlouisfed.org/datatools.html)
# * * Federal Reserve Economic Data (FRED) is a database maintained by the Research division of the Federal Reserve Bank of St. Louis that has more than 765,000 economic time series from 96 sources.[1] The data can be viewed in graphical and text form or downloaded for import to a database or spreadsheet, and viewed on mobile devices. They cover banking, business/fiscal, consumer price indexes, employment and population, exchange rates, gross domestic product, interest rates, monetary aggregates, producer price indexes, reserves and monetary base, U.S. trade and international transactions, and U.S. financial data. The time series are compiled by the Federal Reserve and many are collected from government agencies such as the U.S. Census and the Bureau of Labor Statistics.The economic data published on FRED are widely reported in the media and play a key role in financial markets. In a 2012 Business Insider article titled "The Most Amazing Economics Website in the World", Joe Weisenthal quoted Paul Krugman as saying: "I think just about everyone doing short-order research — trying to make sense of economic issues in more or less real time — has become a FRED fanatic."[Wiki](https://en.wikipedia.org/wiki/Federal_Reserve_Economic_Data#cite_note-2)
#
#
#
#
# ### Fun books to read about big data and data science
# * [Everybody Lies by By *Seth Stephens-Davidowitz* · 2017](https://www.google.com/books/edition/Everybody_Lies/b1BqjwEACAAJ?hl=en)

# %% [markdown]
# ## 4. Code
#
# * [FinGPT/FinNLP](https://github.com/AI4Finance-Foundation)
#
# * WRDS (WRDS subscription needed)
# * * [SAS Macros](https://wrds-www.wharton.upenn.edu/pages/support/research-wrds/research-macros-wrds/)
# * * [Code and Instruction](https://wrds-www.wharton.upenn.edu/pages/wrds-research/applications/)
#
# * [Finance Focused-Github](https://github.com/firmai/financial-machine-learning)
# * [Callable bond Valuation](https://github.com/CinderZhang/valuation-callables-HullWhite)
# * [Book for QuantLib](https://leanpub.com/quantlibpythoncookbook#happiness-guarantee)
# * [Finance Focused-Quantconnect-Over simplified](https://www.quantconnect.com/docs/algorithm-reference/machine-learning)
# * No longer active
# * * [--Quantopian](https://www.quantopian.com/posts/machine-learning-5)

# %% [markdown]
# ## 5. NLP (Natural Language Processing)
#
# ### Best starting point so far
#
# * [HuggingFace Course](https://huggingface.co/course)
# * * [Training/Study Sessions](https://www.youtube.com/watch?v=xRh4Jk8rjfA&list=PLD80i8An1OEF8UOb9N9uSoidOGIMKW96t)
#
# * * Application/Model Examples
#
# * * * [Translation](https://huggingface.co/models?pipeline_tag=translation&sort=downloads)
# * * * [FinBert-SEC](https://huggingface.co/yiyanghkust/finbert-tone)
# * * * * [Talk by the Author](https://www.youtube.com/watch?v=iOZQ_ThzYL0&list=PLPMQCTlcBhvoYqSomzQTxPGRrc4Rock39&index=6&t=42s)
# * * * * [Short example](https://www.youtube.com/watch?v=e_w3FoNmHP4&list=PLPMQCTlcBhvoYqSomzQTxPGRrc4Rock39&index=1)
# * * * [FinBert-ProsusAI](https://huggingface.co/ProsusAI/finbert)
# * * * * [Quick link to Sample code](https://github.com/ProsusAI/finBERT/blob/master/notebooks/finbert_training.ipynb)
#
# * * * [Summarization](https://huggingface.co/tasks/summarization)
#
# ### GPT/ChatGPT/OpenAI
#
# * [Open source books](https://youtu.be/D6F8oxUQfGw)
#
# * [Prompt Engineering for Finance](https://youtu.be/Nl2Cdbao5Ws)
#
# * [FinGPT/FinNLP](https://github.com/AI4Finance-Foundation)
#
# ### Datasets and other resource
#
# * [Reddit and DJIA Daily News on Kaggle](https://www.kaggle.com/aaron7sun/stocknews)
#
# * [Donald Trump's Rallies](https://www.kaggle.com/christianlillelund/donald-trumps-rallies)
# * * The dataset contains the full speeches that Donald Trump gave at 35 of his rallies. Ideal for natural language processing and sentiment analysis.The speeches are provided as txt files in full length.
#
# * * Inspiration
# * * * * NLP with Spacy and txt files: https://siddhantmaharana.github.io/blog/introduction-to-nlp-using-python-and-spacy/
# * * * * Other great NLP notebooks: https://www.kaggle.com/datatattle/covid-19-nlp-text-classification/notebooks
#
# * [Kaggle Datasets](https://www.kaggle.com/datasets)
#
# * [AWS Open Data Registry](https://registry.opendata.aws/)
#
# * [Covid 19-Wish to take it away...](https://datascience.nih.gov/covid-19-open-access-resources)
# * * [John Hopkins](https://coronavirus.jhu.edu/map.html)
#
# ### SEC Edgar-- In a private seperate notebook
#
# ### Other interesting datasets
# * [NLP(Note: Only names no link)](https://www.kaggle.com/general/150720)
# * [NLP(Note: with link)](https://imerit.net/blog/top-25-twitter-datasets-for-natural-language-processing-and-machine-learning-all-pbm/)

# %% [markdown]
# ## Visualization
#
# ### PowerBI
# * [Suggested path](https://docs.microsoft.com/en-us/learn/paths/visualize-data-power-bi/)
#
# ### Excel and PowerBI
# * [All in One](https://www.youtube.com/watch?v=TjSnQ4VDHTE)
#
# ### Tableau
# * [Quick Start](https://www.youtube.com/watch?v=aHVWPYu81JU)
# * [Tableau Education](https://www.tableau.com/community/academic)

# %% [markdown]
# ## SQL and NoSQL
#
# ### NoSQL - MongoDB
# * [MongoDB and Python Tutorial Video](https://www.youtube.com/watch?v=E-1xI85Zog8&t=954s)
# * [MongoDB and Python](https://realpython.com/introduction-to-mongodb-and-python/)
# ### SQL
# * * [SQL on Python](https://realpython.com/python-sql-libraries/)

# %% [markdown]
# ## Miscellaneous
#
# ### In random...order...category
# * [DataFrame---Offical Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html#user-guide)
# * * [10 minutes to Pandas i.e. DataFrame](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
# * * [Pandas Cheat Sheet---Data Wrangling](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
#
# * [Bloomberg](https://www.bloomberg.com/)
# * * [Webinar](https://www.bloomberg.com/professional/blog/webinars/all/?avail=ondemand)
# * * [Excel Add In](https://guides.library.yale.edu/c.php?g=296285&p=1974285)
#
# * [Quantopian ML-Starts here, then Part 2...3...](https://www.quantopian.com/posts/machine-learning-on-quantopian-part-1-basics)
# * * [Quantopian is shuting down by Oct. 31st, 2020..Sadly...](https://www.quantopian.com/posts/quantopians-community-services-are-closing)
# * * * [Is QuantConnect/Backtrader a good alternative? Please comment!](https://randlow.github.io/posts/trading/trading-introduction/)
# * * * [JoinQuant: Another alternative if you know Chinese (中文)](https://randlow.github.io/posts/trading/trading-introduction/)
#
# * [The Quest for AI by Nils Nilsson](http://ai.stanford.edu/~nilsson/QAI/qai.pdf)
#
# * [Kaggle Intro to ML](https://www.kaggle.com/learn/intro-to-machine-learning)
#
# * [Dataiku ML Tutorial](https://academy.dataiku.com/page/ml-practitioner)
#
# * [Intro ML and AI from MIT](https://ocw.mit.edu/resources/res-ll-005-mathematics-of-big-data-and-machine-learning-january-iap-2020/)
#
# * [Quantopian Lectures-Not ML or AI](https://www.quantopian.com/lectures)
